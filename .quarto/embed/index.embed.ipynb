# %% [markdown]
# # JC_Kobe
#
# Norah Jones (The University)
#
# ## Section
#
# This is a simple placeholder for the manuscript’s main document \[@knuth84\].

# %%
a <- 1+1

# %% [markdown]
# 2
#
# DnqsiojfdSDFF <!-- qd,pqsokdP? Will it appear?? --> fkjfdpqzokef
